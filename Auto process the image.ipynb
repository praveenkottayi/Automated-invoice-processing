# %%
import cv2
import matplotlib.pyplot as plt

# %%
im = cv2.imread("2.JPG",0)
plt.imshow(im)
plt.show()

# %%
#blur = cv2.bilateralFilter(im,9,1,1)

# %%
#retval, threshold2 = cv2.threshold(im, 0, 255, cv2.THRESH_BINARY)
retval2,threshold2 = cv2.threshold(im,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
cv2.imshow('threshold',threshold2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('pross.png' , threshold2)
# Out:
# True

# %%
file = open("jet.txt.txt", "r") 
file = open("aa.txt.txt", "r")

# %%
text = (file.read())
text.split("\n")
# Out:
# ['Ticket Issue Date:', 'duly O2, 2018', '\x0c']

# %%
# entities in the file

# %%
import spacy
def getEntity(s):
    nlp = spacy.load('en_core_web_sm')
    #print("1")
    #nlp = joblib.load('spacy_nlp.pkl')
    #print("2")
    parsed_review = nlp(s)
    #from spacy import displacy
    #displacy.serve(parsed_review, style='ent')
    
    for entity in parsed_review.ents:
        if entity.label_ == "DATE":
            print(str(entity) + " : " + str(entity.label_))

# %%
print(getEntity(text))
# Out:
# 2018 : DATE
# None

# %%
# pdf to image

# %%
# smoothing

# %%
# cropping

# %%
from wand.image import Image as Img
with Img(filename='makemytrip_image.pdf', resolution=300) as img:
 img.compression_quality = 99
 img.save(filename='sample_scan.jpg')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\wand\api.py in <module>()
#     179 try:
# --> 180     libraries = load_library()
#     181 except (OSError, IOError):
#
# C:\Anaconda\lib\site-packages\wand\api.py in load_library()
#     134         return libwand, libmagick
# --> 135     raise IOError('cannot find library; tried paths: ' + repr(tried_paths))
#     136
#
# OSError: cannot find library; tried paths: []
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-b20641204207> in <module>()
# ----> 1 from wand.image import Image as Img
#       2 with Img(filename='makemytrip_image.pdf', resolution=300) as img:
#       3  img.compression_quality = 99
#       4  img.save(filename='sample_scan.jpg')
#
# ...
